# %%
#import requests
from pygeocoder import Geocoder
from geopy.geocoders import Nominatim
tg = Nominatim();
import sys
import matplotlib.pyplot as plt
% matplotlib inline
from time import sleep


#Time to open files
ah = open("AnnasHummingbird.csv", "r", errors="ignore");
lb = open("LazuliBunting.csv", "r", errors="ignore");
bs = open("BlackSwift.csv", "r", errors="ignore");
br = open("Brambling.csv", "r", errors="ignore");
hd = open("HarlequinDuck.csv", "r", errors="ignore");
so  = open("SnowyOwl.csv", "r", errors="ignore");

bbox = open("bounding.txt", "w");
#url = 'https://maps.googleapis.com/maps/api/geocode/json?latlng=40.714224,-73.961452&key=AIzaSyDG_6eWWX2LbTrTMrERuZBaRkFht0G6LXk';
#Arrays for the files
"""url = 'https://maps.googleapis.com/maps/api/geocode/json'
params = {'sensor': 'false', 'address': '5515 88th St SW, Mukilteo, WA'}
r = requests.get(url, params=params)
results = r.json()['results']
location = results[0]['geometry']['location']
location['lat'], location['lng']
print(location);"""
###CODE BY DAVID KAHN
#for locate in range(len(SOlist)):
#print(Geocoder.geocode("428 McGilvra Blvd"));
#    SOlocations.append(results.city); #can use route instead of city for name of street
#    sleep(0.1);
#print(SOlocations)
#for ii in ah:
#    aha.append(ii);

#del aha[0];
curlist = []
curmdy = [];
curlocid = [];
curx1 = [];
cury1 = [];
curx2 = [];
cury2 = [];
ahcompcount = 0;

bbox.write("I like c0k");

#print(ahloccomp, ahloccomp2);

struggle = [];
results = [];
#r2 = "";

"""
def struggletrain(dt_parse):
    r2 = "";
    aa = 0;
    grab = 0;
    cc = 0;
    tally = 0;
    count = 0;
    for choochoo in dt_parse:
        curlist.append(choochoo);
    del curlist[0];
    for fku in range(len(curlist)):
        curlist[fku] = curlist[fku].split(","); 
    for chuggachugga in range(len(curlist)):
        curlocid.append(str(curlist[chuggachugga][18]));
        curx1.append(float(curlist[chuggachugga][20]));
        curx2.append(float(curlist[chuggachugga][20]));
        cury1.append(float(curlist[chuggachugga][21]));
        cury2.append(float(curlist[chuggachugga][21]));
    
    #Loc/coord writing arrays
    ucoords = [];
    iloc = [];
    ulocations = [];
    
    #Coord sorting
    while aa < len(curx1):
        if [curx1[aa], cury1[aa]] not in ucoords:
            ucoords.append([curx1[aa], cury1[aa]]);
        aa+=1;
        
    #Grabbing geocode info and refining the data
    while grab < len(ucoords):
        print("Grabbing location", grab, "of", len(ucoords));
        try:
            results = tg.reverse(ucoords[grab]);
            r2 = str(results);
            print("Finished grabbing result", grab, "of", len(ucoords));
            print("Results are:", results);
            print();
            print("We are", grab/len(ucoords)*100,"% of the way there!");
            grab+=1;
        except:
            print("Error grabbing number", grab, "most likely due to timeout, retrying...");
        bbox.write(r2);
        bbox.write("\n");
    #for c in results:
        #iloc.append("");
        #iloc[c] = results[c].split(",");
    #for d in range(len(results)):
        #print("Splitting record", d, "of", len(results));
        #print(results[d][0]);
    #print("Final list length", ucoords);
    #for bleh in range(len(ucoords)):
        #bbox.write(str(ucoords[bleh]));
    bbox.close();
    
    #for a in range(len(ucoords)):
    
struggletrain(ah);
struggletrain(lb);
struggletrain(bs);
struggletrain(br);
struggletrain(hd);
struggletrain(so);"""
dd = 0;
while dd < 1000:
    print(Geocoder.geocode("428 McGilvra Blvd"));
    sleep(0.1);
# Out:
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# 428 McGilvra Blvd E, Seattle, WA 98112, USA
# ...
